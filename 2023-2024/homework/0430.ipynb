# %%
# 1.生成一个数据框，里面有本组同学的姓名性别学号血型年龄

# %%
#2.在刚才的数据框里，追加几个同学，使表中一共有10个同学

# %%
#3.查询血型是A型的同学

# %%
#4.查询身高大于180的同学

# %%
#5.查询身高大于170且血型为O型的同学

# %%
#6.查询年龄小于20且血型为A型的同学

# %%
#7.查询年龄大于20或者血型为B型的同学

# %%
#8.按照身高降序排序

# %%
#9.按照性别分组，并计算每个性别的平均年龄。

# %%
#10.按照血型分组，并计算每个组的平均年龄和身高。

# %%
#11.按照血型分组，并找出每个组中身高最高的学生。

# %%
#12 将学生按照性别分组，并找出每个组中身高最低的两名学生。

# %%
#13 将学生按照血型分组，并计算每个组中男生和女生的比例。
