# %% [markdown]
# # 0.在浏览器选择打印，把本页面打印为pdf再上传！

# %% [markdown]
# # 1.建立一个txt，用两种方式读取它的内容

# %% [markdown]
# # 2.把上次作业任务一生成的dataframe，导出成txt

# %% [markdown]
# # 3.用读取txt的方法读取上一步的txt

# %% [markdown]
# # 4.用pandas的方法读取第二步的txt，此时结果应该是一个表格

# %% [markdown]
# # 5.把上次任务一的dataframe重新导出成txt，分隔符是分号

# %% [markdown]
# # 6.把上次任务二的dataframe导出成csv

# %% [markdown]
# # 7.读取上一步生成的csv

# %% [markdown]
# # 8.读取学习通资源库里任务三文件夹里的两个文件（要先下载到本地再读取），并查看前五行
