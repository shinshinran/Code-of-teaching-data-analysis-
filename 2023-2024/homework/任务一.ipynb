# %% [markdown]
# # 0 安装jupyter

# %% [markdown]
# # 1.用两种方法生成一个dataframe，里面是本组成员信息，包括姓名学号年龄身高

# %% [markdown]
# # 2.增加一列血型

# %% [markdown]
# # 3.选取第一行到第三行的数据

# %% [markdown]
# # 4.选取A型血的数据

# %% [markdown]
# # 5.新增一行成员信息

# %% [markdown]
# # 6.删除刚才新增的一行
