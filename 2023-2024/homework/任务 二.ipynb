# %% [markdown]
# # 1.新建一个dataframe，里面是上学期学过的三门课程，包括课程名称、课程学分、课程学时

# %% [markdown]
# # 2 新增一列课程代码

# %% [markdown]
# # 3.追加一门课程（新建一行）

# %% [markdown]
# # 4. 筛选学时大于40的课程

# %% [markdown]
# # 5.删除课程学时

# %% [markdown]
# # 4.选取偶数行
